# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  puerto natales -51.7236  -72.4875     15.25        44          40
# 1        1        waitangi -43.9535 -176.5597     17.12        94          83
# 2        2    invercargill -46.4000  168.3500     20.01        66         100
# 3        3        ed damer  17.5928   33.9592     21.82        22         100
# 4        4      calderitas  18.5500  -88.2500     28.06        47          40
#
#    Wind Speed Country        Date
# 0       10.29      CL  1707156957
# 1        0.89      NZ  1707156945
# 2        6.71      NZ  1707156958
# 3        5.95      SD  1707156958
# 4        5.14      MX  1707156958

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.8,
    color = "City",
    hover = True
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Drop any rows with null values
ideal_cities = city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["City"].dropna(axis=0)

# Display sample data
ideal_cities_df = pd.DataFrame({"City ID": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["City_ID"],
                                "City": ideal_cities,
                                "Lat": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Lat"],
                                "Lng": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Lng"],
                                "Max Temp": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Max Temp"],
                                "Humidity": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Humidity"],
                                "Cloudiness": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Cloudiness"],
                                "Wind Speed": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Wind Speed"],
                                "Country": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Country"],
                                "Date": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Date"]
                               })
ideal_cities_df
# Out:
#      City ID                      City      Lat       Lng  Max Temp  Humidity  \
# 4          4                calderitas  18.5500  -88.2500     28.06        47
# 5          5                    bonthe   7.5264  -12.5050     28.79        65
# 13        13                    nicoya  10.1483  -85.4520     29.50        60
# 21        21                    avarua -21.2078 -159.7750     28.03        83
# 40        40                      ta`u -14.2336 -169.5144     28.04        78
# 43        43       fale old settlement  -9.3852 -171.2468     29.17        77
# 47        47               cumanayagua  22.1494  -80.2022     28.23        40
# 64        64        brisas de zicatela  15.8369  -97.0419     28.29        69
# 68        68                    safotu -13.4513 -172.4018     28.61        80
# 87        87                  freetown   8.4840  -13.2299     28.84        74
# 100      100               nova vicosa -17.8919  -39.3719     29.33        64
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df.copy()
hotel_df = pd.DataFrame({"City": ideal_cities,
                         "Country": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Country"],
                         "Lat": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Lat"],
                         "Lng": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Lng"],
                         "Humidity": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Humidity"]},
                         index = city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["City_ID"])

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df = pd.DataFrame({"City": ideal_cities,
                         "Country": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Country"],
                         "Lat": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Lat"],
                         "Lng": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Lng"],
                         "Humidity": city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["Humidity"],
                         "Hotel Name": " "},
                         index = city_data_df[city_data_df["Max Temp"].between(28, 30, inclusive="both")]["City_ID"])

# Display sample data
hotel_df
# Out:
#                              City Country      Lat       Lng  Humidity  \
# City_ID
# 4                      calderitas      MX  18.5500  -88.2500        47
# 5                          bonthe      SL   7.5264  -12.5050        65
# 13                         nicoya      CR  10.1483  -85.4520        60
# 21                         avarua      CK -21.2078 -159.7750        83
# 40                           ta`u      AS -14.2336 -169.5144        78
# 43            fale old settlement      TK  -9.3852 -171.2468        77
# 47                    cumanayagua      CU  22.1494  -80.2022        40
# 64             brisas de zicatela      MX  15.8369  -97.0419        69
# 68                         safotu      WS -13.4513 -172.4018        80
# 87                       freetown      SL   8.4840  -13.2299        74
# 100                   nova vicosa      BR -17.8919  -39.3719        64
# 113                       mochudi      BW -24.4167   26.1500        30
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {'api_key':geoapify_key}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, 'Lat']
    longitude = hotel_df.loc[index, 'Lng']
    city = hotel_df.loc[index, 'City']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    params["categories"] = f"accomodation.hotel.{city}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# calderitas - nearest hotel: No hotel found
# bonthe - nearest hotel: No hotel found
# nicoya - nearest hotel: No hotel found
# avarua - nearest hotel: No hotel found
# ta`u - nearest hotel: No hotel found
# fale old settlement - nearest hotel: No hotel found
# cumanayagua - nearest hotel: No hotel found
# brisas de zicatela - nearest hotel: No hotel found
# safotu - nearest hotel: No hotel found
# freetown - nearest hotel: No hotel found
# nova vicosa - nearest hotel: No hotel found
# mochudi - nearest hotel: No hotel found
# atafu village - nearest hotel: No hotel found
# mana - nearest hotel: No hotel found
# bathsheba - nearest hotel: No hotel found
# lima - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: No hotel found
# sabang - nearest hotel: No hotel found
# sao sebastiao - nearest hotel: No hotel found
# porto novo - nearest hotel: No hotel found
# betio village - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.8,
    color = "City",
    hover = True,
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
